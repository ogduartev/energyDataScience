# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

target_url="https://raw.githubusercontent.com/ogduartev/energyDataScience/main/data/stock/sample01.csv"
df = pd.read_csv(target_url)

# %%
df
# Out:
#                     Fecha        AGUA      CARBON         GAS    LIQUIDOS  \
# 0     2015-01-01 00:00:00  187.381526  123.225318  204.977354  971.700598
# 1     2015-01-02 00:00:00  179.863045  119.771853  208.442936  971.705305
# 2     2015-01-03 00:00:00  202.829047  123.878501  213.453856  971.381271
# 3     2015-01-04 00:00:00  230.330204  124.526534  212.540171  947.097082
# 4     2015-01-05 00:00:00  205.850445  125.271973  212.464471  979.080505
# ...                   ...         ...         ...         ...         ...
# 2642  2022-03-27 00:00:00  182.604901  262.813092  697.442903  707.583803
# 2643  2022-03-28 00:00:00  198.853818  262.813092  728.107974  707.583803
# 2644  2022-03-29 00:00:00  202.910992  253.749212  709.119964  707.583803
# 2645  2022-03-30 00:00:00  184.610429  258.967234  718.866090  707.583803
# 2646  2022-03-31 00:00:00  211.776199  264.869713  746.026954  681.372044
#
#       PPP Bolsa Mes  Precio Min. Bolsa diario  Precio Max. Bolsa diario  \
# ...
