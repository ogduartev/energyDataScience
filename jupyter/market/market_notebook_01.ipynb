# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

target_url="https://raw.githubusercontent.com/ogduartev/energyDataScience/main/data/market/sample01.csv"
df = pd.read_csv(target_url,sep=';')

# %%
df
# Out:
#            FECHA      ALBAN  AMOYALAESPERANZA  BARRANQUILLA3  BARRANQUILLA4  \
# 0     2018-04-20  105000.00               NaN         532020         532650
# 1     2018-04-21   75400.00               NaN         532020         532650
# 2     2018-04-22  180000.00               NaN         531670         532300
# 3     2018-04-23  125000.00               NaN         531650         532290
# 4     2018-04-24  117900.00               NaN         531700         532340
# ...          ...        ...               ...            ...            ...
# 1373  2022-03-28  245999.00          123625.0        1545758        1537011
# 1374  2022-03-29  244999.00          121950.0        1545563        1536817
# 1375  2022-03-30   86753.04          102500.0        1545363        1536617
# 1376  2022-03-31   86753.06          117000.0        1545363        1536617
# 1377  2022-04-01   85667.00          130000.0        1538212        1534856
#
# ...

# %%
df[['FECHA','ALBAN']]
# Out:
#            FECHA      ALBAN
# 0     2018-04-20  105000.00
# 1     2018-04-21   75400.00
# 2     2018-04-22  180000.00
# 3     2018-04-23  125000.00
# 4     2018-04-24  117900.00
# ...          ...        ...
# 1373  2022-03-28  245999.00
# 1374  2022-03-29  244999.00
# 1375  2022-03-30   86753.04
# 1376  2022-03-31   86753.06
# 1377  2022-04-01   85667.00
#
# [1378 rows x 2 columns]
